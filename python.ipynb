# %% [markdown]
# # **Python Introduction**
#
# **🐍 1. What is Python?**
#
# Python is a high-level, easy-to-read programming language.
# It’s used for web development, data analytics, machine learning, AI, automation, and more.
#
# 🗣️ "Python is like speaking to the computer in simple English!"
#
# [link text](https://)

# %% [markdown]
#  2**. Why is Python popular in Data Analytics & ML?**
#
#
#  **Reason          | Why it matters**
#
# Simple syntax    | Easy to learn and write.
#
# Big community | Lots of tutorials & help online
#
# Rich libraries | Pandas, NumPy, Matplotlib, Scikit-learn
#
# Versatile | Works for web, automation, AI, etc.
#
# Free & Open Source | Anyone can use and share it

# %% [markdown]
#  3. Syntax Comparison – Python vs Java vs C
# Let see the difference clearly.
#
# Language | Code
#
# Python | print("Hello, world!")
#
# Java | System.out.println("Hello, world!");
#
# C | printf("Hello, world!\n");

# %%
# example simple code
#print("helloworld")

# %% [markdown]
# #Python Comments
#
# Comments can be used to explain Python code.
#
# Comments can be used to make the code more readable.
#
# Comments can be used to prevent execution when testing code.

# %%
#This is a comment
print("Hello, World!")
print("Hello, World!") #This is a comment
# Out:
# Hello, World!
# Hello, World!

# %% [markdown]
# Multiline Comments
#
# Python does not really have a syntax for multiline comments.
#
# To add a multiline comment you could insert a # for each line:

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **python Variables**
#
# Variables are containers for storing data values.
#
# Creating Variables
#
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.

# %%
# example code
list = 5
y = "John"
print(list)
# Out:
# 5

# %%
# example code
#
#xy= "John "
print(x)
# what will be this output?
# Out:
# 5

# %% [markdown]
# **Python - Variable Names**
#
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
# A variable name must start with a letter or the underscore character
#
# A variable name cannot start with a number
#
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#
# Variable names are case-sensitive (age, Age and AGE are three different variables)
#
# A variable name cannot be any of the Python keywords.

# %%
#ExampleGet your own Python Server

#Legal variable names:
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
##Many Values to Multiple Variables

#Python allows you to assign values to multiple variables in one line:
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
#One Value to Multiple Variables

#And you can assign the same value to multiple variables in one line:

x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# # python Built-in Data Types
#
# **In programming, data type is an important concept.**
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories: \
#
# 1.Text Type:	str
#
# 2.Numeric Types:	int, float, complex
#
# 3.Sequence Types:	list, tuple, range
#
# 4.Mapping Type:	dict
#
# 5Set Types:	set,
#
# 6Boolean Type:	bool
#
# 7.Binary Types:	bytes, bytearray,
#
# 8 None Type:	NoneType

# %% [markdown]
# Getting the Data Type
#
# You can get the data type of any object by using the type() function:

# %%
# example
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x_1 = "Hello World"
x_2 = 20
x_3 = 20.5
x_4= 1j
x_5 = ["apple", "banana", "cherry"]
x_6 = ("apple", "banana", "cherry")
x_7 = {"name" : "John", "age" : 36}
x_8 = {"apple", "banana", "cherry"}
x_9 = True
x_10 = b"Hello"
x_11 = bytearray(5)
x_12 = memoryview(bytes(5))

# %% [markdown]
# # Python Numbers
#
# There are three numeric types in Python:
#
# int
# float
# complex
# Variables of numeric types are created when you assign a value to them:

# %%
# example
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#Int

# %%
total_marks = 450
message = str(total_marks)
print(type(message))
# Out:
# <class 'str'>

# %%
# 1. Int, or integer, is a whole number, positive or negative, without decimals, of unlimited length.
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
# 2. Float : Float, or "floating point number" is a number, positive or negative, containing one or more decimals.

x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))

# %%
#3.Complex numbers are written with a "j" as the imaginary part:
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))

# %% [markdown]
# # Type Conversion
#
# You can convert from one type to another with the int(), float(), and complex() methods:

# %%
# example code
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# # Type Casting in Python?
#
# Type Casting means converting one data type into another.

# %%
# automatically converts data type.
a = 5       # int
b = 2.5     # float
result = a + b
print(result)
# Out:
# 7.5

# %%
# Convert string to int
x = "10"
y = (x)  # now y is an integer
print(y + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-51f6b080363f> in <cell line: 0>()
#       2 x = "10"
#       3 y = (x)  # now y is an integer
# ----> 4 print(y + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Convert number to string
age = 25
text = "My age is " + str(age)
print(text)
# Out:
# My age is 25

# %%
x = "hello"
y = int(x)

# what will be this data type ?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-e75929ffd7a4> in <cell line: 0>()
#       1 x = "hello"
# ----> 2 y = int(x)
#       3
#       4 # what will be this data type ?
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %% [markdown]
#  #Python Arithmetic Operators
#
# Arithmetic operators are used to perform basic mathematical operations.
#
# Operator | Symbol | Description | Example | Output
#
# 1.Addition | + | Adds two values | 5 + 3 | 8
#
# 2.Subtraction | - | Subtracts one value from another | 10 - 4 | 6
#
# 3.Multiplication | * | Multiplies two values | 2 * 4 | 8
#
# 4.Division | / | Divides and returns float | 10 / 3 | 3.333...
#
# 5.Floor Division | // | Divides and removes decimal | 10 // 3 | 3
#
# 6.Modulus | % | Returns remainder | 10 % 3 | 1
#
# 7.Exponent | ** | Power (x raised to y) | 2 ** 3 | 8

# %%
a = 10
b = 3

print(a + b)     # 13
print(a - b)     # 7
print(a * b)     # 30
print(a / b)     # 3.333...
print(a // b)    # 3
print(a % b)     # 1
print(a ** b)    # 1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
What is 7 % 2?

Find 4 ** 2

Use // to divide 20 by 6

Predict the output:

# %% [markdown]
# # Python Strings
#
# A string is a sequence of characters enclosed in quotes.
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
# examples
name = "Ravi"
message = 'Welcome to Python class!'
print(name,message)
# Out:
# Ravi Welcome to Python class!

# %%
# Multiline Strings
#You can assign a multiline string to a variable by using three quotes:
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# # Indexing in Python Strings
#
# Indexing means accessing individual characters or elements from a string, list, or any sequence using positions (called indexes).
#
# Python indexing starts from 0 — this is very important for beginners!

# %%
# Example: String Indexing
text = "PYTHON"
print(text[0])
print(text[3])

# %%
 #Negative Indexing
#You can also count from the end using negative numbers:
print(text[-1])

# %%
# some Examples

name = "Thangarasu"
print(name[0])
print(name[-1])

# %% [markdown]
# #Python String Slicing
#
# Slicing means cutting a part of the string using index positions.
# It's like cutting a slice from a cake 🎂🍰
#
# Basic Syntax
#
# string[start : end]
#
# start: index where the slice begins (inclusive)
#
# end: index where it stops (exclusive)

# %%
text = "PYTHON"

# %%
print(text[0:3])
print(text[2:6])
print(text[:4])
print(text[3:])
# Out:
# PYT
# THON
# PYTH
# HON

# %%
text = "PYTHON"
print(text[::2])   # Output: PTO (skip every 2nd letter)
print(text[::-1])  # Output: NOHTYP (reverse string)
# Out:
# PTO
# NOHTYP

# %%
#Practice Questions :

##Get the first 4 letters of "Analytics"

#Get the last 3 letters of "Machine"

##Reverse the string "Python"

# Extract "Data" from "DataScience"

# %% [markdown]
# #python String Concatenation
#
# To concatenate, or combine, two strings you can use the + operator.

# %%
# a = "Hello"
b = "World"
c = a + b
print(c)

# %% [markdown]
# # Python – Modify Strings
#
# In Python, strings are immutable. That means we can’t change the original string directly, but we can create a new modified version using string methods.
#
#
# Python has a set of built-in methods that you can use on strings.
#
# 1. The upper() method returns the string in upper case
# 2. The lower() method returns the string in lower case
# 3. The strip() method removes any whitespace from the beginning or the end
# 4. the split() Splits string into list (by spaces or symbol)
# 5. the replace() Replaces part of the string

# %%
text = "  Welcome to Python class  "

print(text.strip())            # Removes leading/trailing spaces
print(text.upper())            # Converts all to uppercase
print(text.lower())            # Converts all to lowercase
print(text.replace("Python", "Data Science"))  # Replace a word
print(text.split())            # Split into words by space
# Out:
# Welcome to Python class
#   WELCOME TO PYTHON CLASS
#   welcome to python class
#   Welcome to Data Science class
# ['Welcome', 'to', 'Python', 'class']

# %% [markdown]
# #Python Lists
#
# Lists are used to store multiple items in a single variable.
#
# A list in Python is like a collection of items kept together inside square brackets [ ].
#
# You can store many values in one list, like numbers, names, fruits, etc.
#
# A list can change — you can add, remove, or modify items.

# %%
#📘 Examples:
#1.List_of_fruits
fruits =["apple", "banana", "mango"]

# %%
#2. List of numbers
marks = [90, 85, 78, 92]

# %%
#  Mixed list
info = ["Ravi", 25, "Student", 85.5]

# %% [markdown]
#  # ordered- (items have position).
#
#  When we say that lists are ordered, it means that the items have a defined order, and that order will not change.
#
# If you add new items to a list, the new items will be placed at the end of the list.
#
# # Changeable
#
# The list is changeable, meaning that we can change, add, and remove items in a list after it has been created.
#
# # Allow Duplicates
#
# Since lists are indexed, lists can have items with the same value:

# %%
#Example
#Lists allow duplicate values:
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)

# %% [markdown]
# # Accessing Items
# Definition:
# In a list, each item has a position called an index.
# You can use the index number to get (access) any item from the list.
#
# Important:
#
# Index starts from 0, not 1.
#
# So, the first item is at position 0.
#
# # Negative Indexing
#
# Negative indexing means start from the end
#
# -1 refers to the last item, -2 refers to the second last item etc.
#
# # Range of Indexes
#
# You can specify a range of indexes by specifying where to start and where to end the range.
#
# When specifying a range, the return value will be a new list with the specified items.

# %%
# examples

fruits = ["apple", "banana", "mango", "orange"]
print(fruits[0])
print(fruits[2])

#You can also use negative indexing:


print(fruits[-1])   # Output: orange
print(fruits[-2])
# Out:
# apple
# mango
# orange
# mango

# %%
# examle range indexes
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
print(thislist[-2:-5])
# Out:
# ['cherry', 'orange', 'kiwi']
# []

# %% [markdown]
# # Change Item Value
#
# To change the value of a specific item, refer to the index number:
#
# You can change (update) a value inside a list by referring to its index number and assigning a new value.
#
# Remember: Lists are changeable (mutable) — that’s why you can modify them!

# %%
# Example: 1

fruits = ["apple", "banana", "mango", "orange"]
fruits[1] = "grapes"
print(fruits)
# Out:
# ['apple', 'grapes', 'mango', 'orange']

# %%
# ex : 2
numbers = [10, 20, 30, 40]
numbers[2] = 35
print(numbers)
# Out:
# [10, 20, 35, 40]

# %%
# Change a Range of Item Values
# Change the values "banana" and "cherry" with the values "blackcurrant" and "watermelon":
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)

# %%
# Change the second value by replacing it with two new values:
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)

# %%
# change the second and third value by replacing it with one value:
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)

# %%
# Add List Items

#Append Items

# To add an item to the end of the list, use the append() method:

fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)

# %% [markdown]
# # In Python, you can insert (add) a new item at a specific position in the list, without replacing existing items.
#
#  You use the insert() method.
#
# position → the index number where you want to insert.
#
# item → the value you want to add.

# %%
fruits = ["apple", "banana", "mango"]
fruits.insert(1, "grapes")  # Insert "grapes" at position 1
print(fruits)
# Out:
# ['apple', 'grapes', 'banana', 'mango']

# %% [markdown]
# # Method | Purpose |  Example | Result
#
# append() | Adds item at the end | fruits.append("orange") | Add "orange" to list
#
#
# insert() | Adds item at a specific position | fruits.insert(1, "grapes") | Insert "grapes" at position 1
#
#
# remove() | Removes specific item | fruits.remove("banana") | Removes "banana"
#
#
# pop() | Removes item at given index (default last) | fruits.pop(2) | Removes item at index 2
#
#
# clear() | Empties the entire list | fruits.clear() | List becomes empty []
#
# sort() | Sorts the list in ascending order | marks.sort() | List sorted from low to high
#
#
# reverse() | Reverses the list order | marks.reverse() | List reversed
#
#
# copy() | Copies the list | new_list = fruits.copy() | Creates a duplicate list
#
#
# count() | Counts how many times an item appears | fruits.count("apple") | Shows how many "apple"
# ![list_methods.jpg](data:image/jpeg;base64,...)
#
# extend() | Add all items from another list | fruits.extend(["papaya", "berry"]) | Adds multiple fruits

# %%
# example append
fruits = ["apple", "banana", "mango"]

# Add at end
fruits.append("orange")
fruits
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
# # Insert at position
fruits = ["apple", "banana", "mango"]
fruits.insert(1, "grapes")

# %%
# Remove a fruit
fruits = ["apple", "banana", "mango"]
fruits.remove("banana")

# %%
# Remove by index
fruits = ["apple", "banana", "mango"]
fruits.pop(2)

# %%
elements = [12, 3, 4, 45, 5, 2, 3, 42]
sorted_elements = sorted(elements, reverse=True)
print(sorted_elements)

# %%
# # Remove a fruit
elements = [12, 3, 4, 45, 5, 2, 3, 42]
# Sort the fruits
elements.sort()
print(elements)
# Out:
# [2, 3, 3, 4, 5, 12, 42, 45]

# %%
# # Reverse the list
fruits = ["apple", "banana", "mango"]
fruits.reverse()

# %%
# Copy the list

new_fruits = fruits.copy()

# %%
# Count how many "apple"
count_apples = fruits.count("apple")

# %% [markdown]
# # Python Tuples
#
# A tuple is a collection in Python that is ordered, but cannot be changed (it is immutable).
#
#
#
#
# Written inside round brackets ( ).![tuple_methods.jpg](data:image/jpeg;base64,...)
#
# Items are separated by commas ,.
#
# Tuples can store different types of data (numbers, strings, etc.)

# %%
# Example of a Tuple
fruits = ("apple", "banana", "mango")
#Accessing Tuple Items
#Just like lists, you can access items by index:

# %%
#Accessing Tuple Items
# Just like lists, you can access items by index:
print(fruits[0])   # Output: apple
print(fruits[2])   # Output: mango

# %% [markdown]
# # 🔹 Why Use Tuples?
#
# Data Safety: No one can accidentally change your data.
#
# Faster: Tuples are slightly faster than lists.
#
# Example:
#
# Saving days of the week (("Monday", "Tuesday", "Wednesday", ...))
#
# Saving fixed settings like colors, coordinates, etc.
#
#
# # Tips
#
# Tuples are like lists but you cannot change them.
#
# Use ( ) round brackets.
#
# Good for fixed, constant data.

# %%
# Can You Change a Tuple?

fruits[1] = "grapes"
# what will be this get code ?

# %% [markdown]
# # Python Dictionaries
#
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
# A dictionary in Python is a collection of key-value pairs.
# Each key is linked to a value.
#
# Written inside curly brackets {}.
#
# Keys and values are separated by a colon :.
#
# Each key must be unique.

# %% [markdown]
# ![dic_methods.jpg](data:image/jpeg;base64,...)

# %%
# example
student = {
  "name": "Ravi",
  "age": 20,
  "marks": 85
}

# %%
#  How to Access Values
print(student["name"])   # Output: Ravi
print(student["marks"])  # Output: 85

# %% [markdown]
# # Dictionary Items
#
# Dictionary items are ordered, changeable, and do not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
  thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(len(thisdict))

# %% [markdown]
# # definitions for each concept:
#
# **Ordered :** As of Python 3.7, dictionaries keep the order of items in the order they were added. In earlier versions (3.6 and below), dictionaries did not guarantee any specific order.
#
#  **Unordered :** In versions before Python 3.7, dictionaries did not have a fixed order for their items.
#
#  **Changeable**: You can modify a dictionary by adding, changing, or removing items after it has been created.
#
#  **Duplicates Not Allowed**: A dictionary cannot have two items with the same key. Each key must be unique.

# %%
# Ordered (Python 3.7 and above):
my_dict = {'a': 1, 'b': 2, 'c': 3}
for key, value in my_dict.items():
    print(key, value)
# Out:
# a 1
# b 2
# c 3

# %%
# Changeable (Mutable)

my_dict = {'a': 1, 'b': 2}
# Adding an item
my_dict['c'] = 3
# Modifying an existing item
my_dict['b'] = 10
# Removing an item
del my_dict['a']
print(my_dict)
# Out:
# {'b': 10, 'c': 3}

# %%
my_dict = {
    'a': 1,
    'b': 2,
    'a': 3  # This will overwrite the previous 'a'
}

print(my_dict)
# Out:
# {'a': 3, 'b': 2}

# %%
# Duplicates Not Allowed:
my_dict = {'a': 1, 'b': 2}
my_dict['a'] = 10  # This will update the value for key 'a'
print(my_dict)
# Out:
# {'a': 10, 'b': 2}

# %%
#  example accesing elements

my_dict = {
    "name": "Thangarasu",
    "age": 30,
    "skills": ["Python", "ML", "NLP","DL","Genai"]
}

# %%
#Accessing Elements

#Using square brackets []
print(my_dict["name"])
print(my_dict["skills"])
# Out:
# Thangarasu
# ['Python', 'ML', 'NLP', 'DL', 'Genai']

# %%
# Using .get() method (safer, avoids KeyError)
# ✅ 1. dict.get(key[, default])

print(my_dict.get("age"))          # Output: 30
print(my_dict.get("location"))     # Output: None (doesn't crash)
print(my_dict.get("location", "Not Found"))
# Out:
# 30
# None
# Not Found

# %%
# ✅ 2. dict.keys()
#Returns a view of all the keys.

print(my_dict.keys())
# Out:
# dict_keys(['name', 'age', 'skills'])

# %%
#✅ 3. dict.values()

# returns a view of all the values.

print(my_dict.values())
# Out:
# dict_values(['Thangarasu', 30, ['Python', 'ML', 'NLP', 'DL', 'Genai']])

# %%
#✅ 4. dict.items()

# Returns a view of all key-value pairs (tuples).

print(my_dict.items())
# Out:
# dict_items([('name', 'Thangarasu'), ('age', 30), ('skills', ['Python', 'ML', 'NLP', 'DL', 'Genai'])])

# %%
my_dict
# Out:
# {'name': 'Thangarasu',
#  'age': 30,
#  'skills': ['Python', 'ML', 'NLP', 'DL', 'Genai']}

# %%
# ✅ 5. dict.update([other_dict])

# Updates the dictionary with elements from another dictionary.

my_dict.update({"location": "Chennai"})
print(my_dict)
# Out:
# {'name': 'Thangarasu', 'age': 30, 'skills': ['Python', 'ML', 'NLP', 'DL', 'Genai'], 'location': 'Chennai'}

# %%
# ✅ 6. dict.pop(key[, default])
#Removes the item with the specified key.

my_dict.pop("age")
print(my_dict)
# Out:
# {'name': 'Thangarasu', 'skills': ['Python', 'ML', 'NLP', 'DL', 'Genai'], 'location': 'Chennai'}

# %%
# ✅ 7. dict.popitem()

# Removes the last inserted key-value pair.

my_dict.popitem()
print(my_dict)
# Out:
# {'name': 'Thangarasu', 'skills': ['Python', 'ML', 'NLP', 'DL', 'Genai']}

# %%
# ✅ 8. dict.clear()
# Removes all elements from the dictionary.

my_dict.clear()
print(my_dict)
# Out:
# {}

# %%
# ✅ 9. dict.copy()

# Returns a shallow copy of the dictionary.

my_dict = {
    "name": "Thangarasu",
    "age": 30,
    "skills": ["Python", "ML", "NLP","DL","Genai"],
    "location" : "vellore"
}

new_dict = my_dict.copy()
print(new_dict)
# Out:
# {'name': 'Thangarasu', 'age': 30, 'skills': ['Python', 'ML', 'NLP', 'DL', 'Genai'], 'location': 'vellore'}

# %%
# ✅ 10. dict.setdefault(key[, default])

# Returns the value if the key exists; otherwise inserts the key with the default value.

new_dict.setdefault("location", "Chennai")
print(my_dict)
# Out:
# {'name': 'Thangarasu', 'age': 30, 'skills': ['Python', 'ML', 'NLP', 'DL', 'Genai'], 'location': 'vellore'}

# %%
#  Accessing Nested Elements

nested_dict = {
    "person": {
        "name": "Thangarasu",
        "details": {
            "age": 30,
            "city": "Chennai"
        }
    }
}

print(nested_dict["person"]["details"]["city"])  # Output: Chennai

# %% [markdown]
# # Python Sets
#
# A set is:
#
# Sets are used to store multiple items in a single variable.
#
# An unordered, unindexed collection.
#
# No duplicate elements.
#
# Defined using curly braces {} or the set() constructor.

# %% [markdown]
# ![set_methods.jpg](data:image/jpeg;base64,...)

# %%
#Create a Set:

thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
## Using set() function
s2 = set([1, 2, 2, 3])
print(s2)
# Out:
# {1, 2, 3}

# %%
#Duplicate values will be ignored:

thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
# 🔹 1. add(elem)

# Adds a single element.

s = {1, 2}
s.add(3)
print(s)  # {1, 2, 3}

# %%
#🔹 2. update(iterable)
#Adds multiple elements from an iterable (like list, tuple, etc.).
s.update([4, 5])
print(s)  # {1, 2, 3, 4, 5}

# %%
# 🔹 3. remove(elem)
# Removes an element. Raises KeyError if the element is not found.

s.remove(5)
# s.remove(10)  # KeyError if 10 not in set

# %%
##🔹 4. discard(elem)
#Removes an element if it exists. No error if not found.

s.discard(10)  # No error

# %%
#🔹 5. pop()
#Removes and returns an arbitrary (random) element.

val = s.pop()
print(val)

# %%
 #6. clear()
#Removes all elements from the set.

s.clear()
print(s)  # Outpu

# %%
#  7. copy()
#Returns a shallow copy of the set.

a = {1, 2}
b = a.copy()
print(b)

# %%
#🧠 Set Operations Methods
#🔹 8. union(other_set) or |
#Combines sets.

a = {1, 2}
b = {2, 3}
print(a.union(b))  # {1, 2, 3}

# %%
#  9. intersection(other_set) or &

#Gets common elements.

print(a.intersection(b))

# %%
#  10. difference(other_set) or -
# Gets elements in a but not in b.

print(a.difference(b))  # {1}

# %%
#🔹 11. symmetric_difference(other_set) or ^
#Gets elements in either set but not both.

print(a.symmetric_difference(b))  # {1, 3}

# %% [markdown]
# # summary of the list,tuple,dict,set
#
#
# ![summary.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # List Practice Questions
#
# 1.Create a list with numbers from 1 to 10
#
# 2.Add the number 11 to the end of the list.
#
# 3.Remove the number 5 from the list.
#
# 4.Reverse the list.
#
# 5.Find the maximum and minimum number in the list.
#
# 6.Sort a list of names alphabetically.
#
# 7.Count how many times the number 3 appears in a list.
#
#
#
#
#
# #Tuple Practice Questions
#
# 1.Create a tuple with five fruits.
#
# 2.Access the third item in the tuple.
#
# 3.Try to change a value in the tuple and observe the result.
#
# 4.Convert a tuple to a list.
#
# 5.Slice the tuple to get only the first 3 elements.
#
# # Set Practice Questions
#
# 1.Create a set with values: 1, 2, 2, 3, 4.
#
# 2.Add the number 5 to the set.
#
# 3.Find the union of two sets.
#
# 4.Find the intersection between two sets.
#
# # Dictionary Practice Questions
#
# 1.Create a dictionary with keys: name, age, city.
#
# 2.Access the value of the age key.
#
# 3.Add a new key-value pair: country: India.
#
# 4.Update the value of city.
#
# 5.Use get() to access a key that may not exist.

# %% [markdown]
# # if - elif - else (Decision Making)
#
# Think of it like making choices:
#
# 🔸 “If this is true, do this. If not, try the next condition. If nothing is true, do something else.”
#
#
#
# ![if else operations.jpg](data:image/jpeg;base64,...)

# %%
# Example if statement

a = 33
b = 200
if b > a:
  print("b is greater than a")

# %%
# Elif  example

#The elif keyword is Python's way of saying "if the previous conditions were not true, then try this condition".

a = 33
b = 33
if b > a:

   print("b is greater than a")
elif a == b:
  print("a and b are equal")

# In this example a is equal to b, so the first condition is not true, but the elif condition is true, so we print to screen that "a and b are equal".
# Out:
# a and b are equal

# %%
# Else staement example

# The else keyword catches anything which isn't caught by the preceding conditions.

a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")

# %% [markdown]
#  # And
#
# The and keyword is a logical operator, and is used to combine conditional statements:
#
# ✅ True and True → True
# ❌ Any False → Entire condition becomes False

# %%
# example

a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# # Or
#
# The or keyword is a logical operator, and is used to combine conditional statements:
#
# At least one True is enough
#
# ✅ True or False → True
# ❌ Only False or False → False

# %%
# example
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# # Not
#
# The not keyword is a logical operator, and is used to reverse the result of the conditional statement:

# %%
# a = 33
b = 200
if not a > b:
  print("a is NOT greater than b")

# %%
# examples

marks = 85

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
else:
    print("Grade: C")
# Out:
# Grade: B

# %% [markdown]
# # Python For Loops
#
# What is a loop in Python?
#
# A loop is used to repeat a block of code multiple times.
#
# 📌 Example in real life:
# If you want to say "Hello" 5 times, you don't write it 5 times — you use a loop!
#
# A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
#
# This is less like the for keyword in other programming languages, and works more like an iterator method as found in other object-orientated programming languages.
#
# With the for loop we can execute a set of statements, once for each item in a list, tuple, set etc.

# %%
# A for loop is used to repeat something for each item in a list, string, or range of numbers.

for i in range(1, 6):
    print(i)

# %%
# Example 2: Loop through a list

fruits = ["apple", "banana", "mango"]

for fruit in fruits:
    print(fruit)

# %%
#2. Looping Through a String
#📘 You can also loop through each letter in a word.


for x in "banana":
    print(x)

# %%
# 3. break Statement
#📘 Used to stop the loop early.

fruits = ["apple", "banana", "cherry"]

for x in fruits:
    print(x)
    if x == "banana":
        break

# %%
for x in fruits:
    if x == "banana":
        break
    print(x)

# %%
# 4. continue Statement
# Used to skip one item in the loop.

for x in fruits:
    if x == "banana":
        continue
    print(x)

# %%
 #5. range() Function
# range(n) gives numbers from 0 to (n-1)
for x in range(6):
    print(x)

# %%
#  You can also set start and stop:

for x in range(2, 6):
    print(x)

# %%
# You can also set step size:

for x in range(2, 10, 2):
    print(x)

# %%
# 6. else with for loop
# else will run after the loop finishes.

for x in range(3):
    print(x)
else:
    print("Loop ended!")

# %%
# if we use break, else won’t run:

for x in range(6):
    if x == 3:
        break
    print(x)
else:
    print("Loop ended!")  # ← This won't run

# %% [markdown]
# #The while Loop
#
# With the while loop we can execute a set of statements as long as a condition is true.
#
# 🔁 Syntax:
#
# while condition:
#     # do something

# %%
i = 1

while i <= 5:
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Using break in a while loop

i = 1

while i <= 5:
    print(i)
    if i == 3:
        break
    i += 1

# %% [markdown]
# # Warning: Infinite Loop
# Make sure the condition becomes False at some point, or it will run forever
#
# while True:
#     print("I will run forever!")  # press stop to break it!

# %%
n = int(input())

arr = list(map(int, input().split()))

for i in range(n):
    for j in range(0, n - i - 1):  # Reduce range each pass
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]

print(arr)
